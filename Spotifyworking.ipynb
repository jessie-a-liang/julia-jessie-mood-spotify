# %%
import spotipy
import json
import webbrowser
import pandas
import urllib.request
import spotipy.util as util

# %%
credentials = "spotify_keys.json"
with open(credentials, "r") as keys:
    api_tokens = json.load(keys)

# %%
client_id = api_tokens["client_id"]
client_secret = api_tokens["client_secret"]
redirectURI = api_tokens["redirect"]
username = api_tokens["username"]

# %%
username
# Out:
# 'jessiealiang'

# %%
scope = 'user-read-private user-read-playback-state user-modify-playback-state playlist-modify-public user-read-recently-played'
token = util.prompt_for_user_token(username, scope, client_id=client_id,
                           client_secret=client_secret,
                           redirect_uri=redirectURI)

# %%
sp = spotipy.Spotify(auth=token)

# %%
recently_played = sp.current_user_recently_played(limit=1,after=None, before=None)
recently_played
# Out:
# {'items': [{'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ka3k9K2WStR52UJVtbJZW'},
#        'href': 'https://api.spotify.com/v1/artists/3Ka3k9K2WStR52UJVtbJZW',
#        'id': '3Ka3k9K2WStR52UJVtbJZW',
#        'name': 'Mild Minds',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Ka3k9K2WStR52UJVtbJZW'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Eh8MVthc1OiqAQOgQClVl'},
#      'href': 'https://api.spotify.com/v1/albums/2Eh8MVthc1OiqAQOgQClVl',
#      'id': '2Eh8MVthc1OiqAQOgQClVl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273946d7a6bceef77dce9cc0516',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02946d7a6bceef77dce9cc0516',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851946d7a6bceef77dce9cc0516',
#        'width': 64}],
#      'name': 'MOOD',
#      'release_date': '2020-03-13',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:2Eh8MVthc1OiqAQOgQClVl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ka3k9K2WStR52UJVtbJZW'},
#       'href': 'https://api.spotify.com/v1/artists/3Ka3k9K2WStR52UJVtbJZW',
#       'id': '3Ka3k9K2WStR52UJVtbJZW',
#       'name': 'Mild Minds',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Ka3k9K2WStR52UJVtbJZW'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 277681,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA2P1822115'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2aT8QoKvwvhgx9PURO4DEP'},
#     'href': 'https://api.spotify.com/v1/tracks/2aT8QoKvwvhgx9PURO4DEP',
#     'id': '2aT8QoKvwvhgx9PURO4DEP',
#     'is_local': False,
#     'name': 'SWIM',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/46b4ccb5ccc29af3c6443d648bec2b9b562fdec5?cid=de18966e51ef4f3a8be7f2aa426df65b',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:2aT8QoKvwvhgx9PURO4DEP'},
#    'played_at': '2023-11-28T19:21:41.066Z',
#    'context': {'type': 'artist',
#     'external_urls': {'spotify': 'https://open.spotify.com/artist/4oLeXFyACqeem2VImYeBFe'},
#     'href': 'https://api.spotify.com/v1/artists/4oLeXFyACqeem2VImYeBFe',
#     'uri': 'spotify:artist:4oLeXFyACqeem2VImYeBFe'}}],
#  'next': 'https://api.spotify.com/v1/me/player/recently-played?before=1701199301066&limit=1',
#  'cursors': {'after': '1701199301066', 'before': '1701199301066'},
#  'limit': 1,
#  'href': 'https://api.spotify.com/v1/me/player/recently-played?limit=1'}

# %%
song = recently_played['items']
song
# Out:
# [{'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ka3k9K2WStR52UJVtbJZW'},
#       'href': 'https://api.spotify.com/v1/artists/3Ka3k9K2WStR52UJVtbJZW',
#       'id': '3Ka3k9K2WStR52UJVtbJZW',
#       'name': 'Mild Minds',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Ka3k9K2WStR52UJVtbJZW'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Eh8MVthc1OiqAQOgQClVl'},
#     'href': 'https://api.spotify.com/v1/albums/2Eh8MVthc1OiqAQOgQClVl',
#     'id': '2Eh8MVthc1OiqAQOgQClVl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273946d7a6bceef77dce9cc0516',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02946d7a6bceef77dce9cc0516',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851946d7a6bceef77dce9cc0516',
#       'width': 64}],
#     'name': 'MOOD',
#     'release_date': '2020-03-13',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:2Eh8MVthc1OiqAQOgQClVl'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ka3k9K2WStR52UJVtbJZW'},
#      'href': 'https://api.spotify.com/v1/artists/3Ka3k9K2WStR52UJVtbJZW',
#      'id': '3Ka3k9K2WStR52UJVtbJZW',
#      'name': 'Mild Minds',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Ka3k9K2WStR52UJVtbJZW'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 277681,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA2P1822115'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2aT8QoKvwvhgx9PURO4DEP'},
#    'href': 'https://api.spotify.com/v1/tracks/2aT8QoKvwvhgx9PURO4DEP',
#    'id': '2aT8QoKvwvhgx9PURO4DEP',
#    'is_local': False,
#    'name': 'SWIM',
#    'popularity': 60,
#    'preview_url': 'https://p.scdn.co/mp3-preview/46b4ccb5ccc29af3c6443d648bec2b9b562fdec5?cid=de18966e51ef4f3a8be7f2aa426df65b',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:2aT8QoKvwvhgx9PURO4DEP'},
#   'played_at': '2023-11-28T19:21:41.066Z',
#   'context': {'type': 'artist',
#    'external_urls': {'spotify': 'https://open.spotify.com/artist/4oLeXFyACqeem2VImYeBFe'},
#    'href': 'https://api.spotify.com/v1/artists/4oLeXFyACqeem2VImYeBFe',
#    'uri': 'spotify:artist:4oLeXFyACqeem2VImYeBFe'}}]

# %%
artist_id = [song[0]['track']['artists'][0]['id']]
artist_id
# Out:
# ['3Ka3k9K2WStR52UJVtbJZW']

# %%
track_id = [song[0]['track']['id']]
track_id
# Out:
# ['2aT8QoKvwvhgx9PURO4DEP']

# %%
oura = 0.5
tfl = 118
weather = 0.7
news = 0.9

# %%
 tracks = sp.recommendations(artist_id,track_id, target_danceability=news, target_energy=oura, target_valence=weather, target_tempo=tfl, genres=None, limit=15)
track_list = tracks['tracks']
uri_list = []
for track in track_list:
    uri_list.append(track['uri'])

uri_list
# Out:
# ['spotify:track:1vMGIZbIkpaLSagdF2ygcV',
#  'spotify:track:5N6BhjTwtWa4keibdHs45q',
#  'spotify:track:1DPZj1aBYDjY3245z0Ri8K',
#  'spotify:track:4QEbcJ9BIiiFgch6so8IDt',
#  'spotify:track:7d0VJeMvhtTwnm7h5qBzXo',
#  'spotify:track:56s8emjdpq3KjecMlyIBkb',
#  'spotify:track:3p7tnkOpYL5WH4IaRzLZ5e',
#  'spotify:track:3oGcjB8hAH7LVlqHX6fpWn',
#  'spotify:track:2YgO4Laiw37ILWYaueb023',
#  'spotify:track:5LtwyYe2xBywQCZzy7paUG',
#  'spotify:track:2N2rUGd8RfwuGzNeZEOlNd',
#  'spotify:track:4zqSXSyqsEGnWl2Gyb5OV9',
#  'spotify:track:2E9pe2XovilcquBjoIUwvD',
#  'spotify:track:2yQweA8nCYuzFj15LiOb41',
#  'spotify:track:21ErLxJOUYnrFTFrJIlJuW']

# %%
# my_playlist = sp.user_playlist_create(user=username, name="today", public=True,
#                                       description="Songs for today")
# results = sp.user_playlist_add_tracks(username, my_playlist['id'], track_selection_list)
# print(results)

# %%
my_playlist = sp.user_playlist_create(user=username, name="today", public=True, description="Songs for today")
a = sp.user_playlist_add_tracks(username, my_playlist['id'], uri_list)
a
# Out:
# {'snapshot_id': 'Myw0OTY5OTg5MmQ2MzczMmRhY2ZjMjZmMGExZGQxMzE1ODcyZTQ3ODhi'}
